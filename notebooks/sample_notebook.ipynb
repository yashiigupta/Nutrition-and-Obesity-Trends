# %% [markdown]
# <a href="https://colab.research.google.com/github/yashiigupta/Nutrition-and-Obesity-Trends/blob/main/notebooks/sample_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("this is a sample notebook")
# Out:
# this is a sample notebook
