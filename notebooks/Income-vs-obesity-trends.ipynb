# %%
import pandas as pd

# %%
df_gdp = pd.read_csv('../data/clean_gdp_data.csv')
df_obesity = pd.read_csv("../data/clean_obesity_data.csv")

# %%
display(df_gdp)
display(df_obesity)
# Out:
#                     Country Name Country Code      2000      2001      2002  \
# 0                          Aruba          ABW    1.8735    1.8965    1.9618
# 1    Africa Eastern and Southern          AFE  287.2017  260.9922  267.8150
# 2                    Afghanistan          AFG    3.5214    2.8136    3.8257
# 3     Africa Western and Central          AFW  142.1401  150.0585  179.3901
# 4                         Angola          AGO    9.1296    8.9361   15.2856
# ..                           ...          ...       ...       ...       ...
# 254                       Kosovo          XKX    5.1818    5.1818    5.1818
# 255                  Yemen, Rep.          YEM    9.6793    9.8530   10.6934
# 256                 South Africa          ZAF  151.7528  135.4299  129.0876
# 257                       Zambia          ZMB    3.6006    4.0944    4.1939
# 258                     Zimbabwe          ZWE    6.6900    6.7774    6.3421
#
# ...
